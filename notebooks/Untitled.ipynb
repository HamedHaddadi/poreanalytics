# %%
from random_packs import LubaStill2D

# %%
luba = LubaStill2D(100, 16, 8, 0.1, 0.001)

# %%
luba.dispense()

# %%
luba()
# Out:
# ('running ', 0, 'of ', 100)
# ('now the radius is = ', 0.0010000000474974513)
# ('WALL colliding object id is = ', 15)
# ('velocity of wall colliding object BEFORE is ', 0.43128466606140137, 0.6014406681060791)
# collision with walls
# ('velocity of wall colliding object AFTER is ', -0.43128466606140137, 0.6014406681060791)
# ('running ', 1, 'of ', 100)
# ('now the radius is = ', 0.0010000091278925538)
# ('WALL colliding object id is = ', 15)
# ('velocity of wall colliding object BEFORE is ', -0.43128466606140137, 0.6014406681060791)
# collision with walls
# ('velocity of wall colliding object AFTER is ', -0.43128466606140137, -0.6014406681060791)
# ('running ', 2, 'of ', 100)
# ('now the radius is = ', 0.0010000182082876563)
# ('WALL colliding object id is = ', 15)
# ('velocity of wall colliding object BEFORE is ', -0.43128466606140137, -0.6014406681060791)
# collision with walls
# ('velocity of wall colliding object AFTER is ', 0.43128466606140137, -0.6014406681060791)
# ...

# %%
luba.max_x
# Out:
# 6.502974987030029

# %%
for obj in luba.objects:
    print(obj.vx, obj.vy)
# Out:
# 0.6619306802749634 0.05000000074505806
# 0.05940043926239014 0.05000000074505806
# -0.23316872119903564 0.05000000074505806
# 0.37354540824890137 0.05000000074505806
# 0.6923338174819946 0.05000000074505806
# -0.16800129413604736 0.05000000074505806
# 0.5243960618972778 0.05000000074505806
# 0.4721637964248657 0.05000000074505806
# 0.5128209590911865 0.05000000074505806
# -0.5059221982955933 0.05000000074505806
# 0.303037166595459 0.05000000074505806
# 0.7694143056869507 0.05000000074505806
# 0.532989501953125 0.05000000074505806
# -0.4501863121986389 0.05000000074505806
# -0.02696526050567627 0.05000000074505806
# 0.8093061447143555 0.05000000074505806
# -0.3619341254234314 0.05000000074505806
# -0.4677109718322754 0.05000000074505806
# -0.8525018692016602 0.05000000074505806
# -0.4458364248275757 0.05000000074505806
# 0.8819599151611328 0.05000000074505806
# 0.5404090881347656 0.05000000074505806
# -0.9682645797729492 0.05000000074505806
# 0.25908684730529785 -0.15000000596046448
# ...
